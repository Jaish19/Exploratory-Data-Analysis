# %% [markdown]
# # **Plotting**

# %%
# !git clone https://github.com/Jaish19/DIABETES-CLASSIFICATION---MACHINE-LEARNING.git
# Out:
# Cloning into 'DIABETES-CLASSIFICATION---MACHINE-LEARNING'...
# remote: Enumerating objects: 16, done.
# remote: Counting objects: 100% (16/16), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 16 (delta 4), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (16/16), 187.11 KiB | 1.95 MiB/s, done.
# Resolving deltas: 100% (4/4), done.

# %% [markdown]
# # General plot.**py**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv(r"/content/DIABETES-CLASSIFICATION---MACHINE-LEARNING/kaggle_diabetes.csv")
print(df.head(5))

ax = sns.scatterplot(x="Age", y="BMI", hue="Outcome", size="BloodPressure", data=df)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            2      138             62             35        0  33.6
# 1            0       84             82             31      125  38.2
# 2            0      145              0              0        0  44.2
# 3            0      135             68             42      250  42.3
# 4            1      139             62             41      480  40.7
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.127   47        1
# 1                     0.233   23        0
# 2                     0.630   31        1
# 3                     0.365   24        1
# 4                     0.536   21        0

# %%
# ax = sns.boxplot(x="Outcome", y="BMI", data=df)

ax = sns.boxplot(x="Outcome", y="Pregnancies", data=df)

# %%
# Plotting the Outcomes based on the number of dataset entries
plt.figure(figsize=(10,7))
sns.countplot(x='Outcome', data=df)

# Removing the unwanted spines
#plt.gca().spines['top'].set_visible(False)
#plt.gca().spines['right'].set_visible(False)

# Headings
plt.xlabel('Outcome')
plt.ylabel('Count')

plt.show()

# %%
ax = sns.scatterplot(x="Age", y="BMI",hue="Outcome",size = "sepal.width",data=dataframe)

# %%
sns.pairplot(df, hue='Outcome')
